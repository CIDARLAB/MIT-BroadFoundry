# %%
import dbmap

# %%
import interact
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
f = interact.connection('combo12', 'combo12')

# %%
f.import_parts(interact.parse_data(open('../library_generation/projects/combo_test/parts.tab', "U")))
# Out:
# {'label_x_offset': -2.0, 'part_name': 'C_AmtR', 'color': [1.0, 0.75, 0.17], 'label': 'AmtR', 'length': 100.0, 'label_style': 'italic', 'linewidth': 1.0, 'type': 'CDS', 'label_y_offset': -0.5}
# {'label_x_offset': -2.0, 'part_name': 'C_LitR', 'color': [0.38, 0.82, 0.32], 'label': 'LitR', 'length': 100.0, 'label_style': 'italic', 'linewidth': 1.0, 'type': 'CDS', 'label_y_offset': -0.5}
# {'label_x_offset': -2.0, 'part_name': 'C_BM3R1', 'color': [0.95, 0.3, 0.25], 'label': 'BM3R1', 'length': 100.0, 'label_style': 'italic', 'linewidth': 1.0, 'type': 'CDS', 'label_y_offset': -0.5}
# {'label_x_offset': -2.0, 'part_name': 'C_SrpR', 'color': [0.38, 0.65, 0.87], 'label': 'SrpR', 'length': 100.0, 'label_style': 'italic', 'linewidth': 1.0, 'type': 'CDS', 'label_y_offset': -0.5}
# {'label_x_offset': -2.0, 'part_name': 'C_PhlF', 'color': [0.55, 0.35, 0.64], 'label': 'PhlF', 'length': 100.0, 'label_style': 'italic', 'linewidth': 1.0, 'type': 'CDS', 'label_y_offset': -0.5}
# {'color': [0.95, 0.3, 0.25], 'length': 25.0, 'type': 'Promoter', 'part_name': 'P_BM3R1'}
# {'color': [1.0, 0.75, 0.17], 'length': 25.0, 'type': 'Promoter', 'part_name': 'P_AmtR'}
# {'color': [0.38, 0.82, 0.32], 'length': 25.0, 'type': 'Promoter', 'part_name': 'P_LitR'}
# {'color': [0.38, 0.65, 0.87], 'length': 25.0, 'type': 'Promoter', 'part_name': 'P_SrpR'}
# {'color': [0.55, 0.35, 0.64], 'length': 25.0, 'type': 'Promoter', 'part_name': 'P_PhlF'}
# {'length': 5.0, 'linewidth': 1.0, 'type': 'Ribozyme', 'part_name': 'Z_Rib'}
# {'length': 50.0, 'type': 'Terminator', 'part_name': 'T_Ter'}
# {'color': [0.0, 0.0, 0.0], 'length': 30.0, 'type': 'RBS', 'part_name': 'R_RBS'}

# %%
f.load_db()

# %%
f.import_designs(interact.parse_data(open('../library_generation/projects/combo_test/designs.tab', "U")))
# Out:
# going...
# going...
# going...
# going...
# [[[<dbmap.Part object at 0x7f7d9938c590>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901c750>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901c790>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901c850>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901c950>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]]]
# [[[<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9938c590>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c750>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c790>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c850>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c950>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]]]
# [[[<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9938c590>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c750>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c790>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c850>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c950>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]]]
# [[[<dbmap.Part object at 0x7f7d9901ca50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9938c590>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ca50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c750>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ca50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c790>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ca50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c850>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901ca50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c950>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cb50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9938c590>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cb50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c750>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cb50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c790>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cb50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c850>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cb50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c950>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cc50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9938c590>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cc50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c750>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cc50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c790>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cc50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c850>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cc50>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c950>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cd10>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9938c590>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cd10>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c750>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[<dbmap.Part object at 0x7f7d9901cd10>, 1], [<dbmap.Part object at 0x7f7d99083f50>, 1], [<dbmap.Part object at 0x7f7d9901ce90>, 1], [<dbmap.Part object at 0x7f7d9901c790>, 1], [<dbmap.Part object at 0x7f7d99083f90>, 1]], [[< ...

# %%
f.load_db()

# %%
list(f.mdb['designparts'].find())
# Out:
# [{u'_id': ObjectId('54795ac4446f5279bd637c3d'), u'dpid': 1},
#  {u'_id': ObjectId('54795ac4446f5279bd637c3e'), u'dpid': 2},
#  {u'_id': ObjectId('54795ac4446f5279bd637c3f'), u'dpid': 3},
#  {u'_id': ObjectId('54795ac4446f5279bd637c40'), u'dpid': 4},
#  {u'_id': ObjectId('54795ac4446f5279bd637c41'), u'dpid': 5},
#  {u'_id': ObjectId('54795ac4446f5279bd637c43'), u'dpid': 6},
#  {u'_id': ObjectId('54795ac4446f5279bd637c44'), u'dpid': 7},
#  {u'_id': ObjectId('54795ac4446f5279bd637c45'), u'dpid': 8},
#  {u'_id': ObjectId('54795ac4446f5279bd637c46'), u'dpid': 9},
#  {u'_id': ObjectId('54795ac4446f5279bd637c47'), u'dpid': 10},
#  {u'_id': ObjectId('54795ac4446f5279bd637c49'), u'dpid': 11},
#  {u'_id': ObjectId('54795ac4446f5279bd637c4a'), u'dpid': 12},
#  {u'_id': ObjectId('54795ac4446f5279bd637c4b'), u'dpid': 13},
#  {u'_id': ObjectId('54795ac4446f5279bd637c4c'), u'dpid': 14},
#  {u'_id': ObjectId('54795ac4446f5279bd637c4d'), u'dpid': 15},
#  {u'_id': ObjectId('54795ac4446f5279bd637c4f'), u'dpid': 16},
#  {u'_id': ObjectId('54795ac4446f5279bd637c50'), u'dpid': 17},
#  {u'_id': ObjectId('54795ac4446f5279bd637c51'), u'dpid': 18},
#  {u'_id': ObjectId('54795ac4446f5279bd637c52'), u'dpid': 19},
#  {u'_id': ObjectId('54795ac4446f5279bd637c53'), u'dpid': 20},
#  {u'_id': ObjectId('54795ac4446f5279bd637c55'), u'dpid': 21},
#  {u'_id': ObjectId('54795ac4446f5279bd637c56'), u'dpid': 22},
#  {u'_id': ObjectId('54795ac4446f5279bd637c57'), u'dpid': 23},
#  {u'_id': ObjectId('54795ac4446f5279bd637c58'), u'dpid': 24},
#  {u'_id': ObjectId('54795ac4446f5279bd637c59'), u'dpid': 25},
#  {u'_id': ObjectId('54795ac4446f5279bd637c5b'), u'dpid': 26},
#  {u'_id': ObjectId('54795ac4446f5279bd637c5c'), u'dpid': 27},
#  {u'_id': ObjectId('54795ac4446f5279bd637c5d'), u'dpid': 28},
#  {u'_id': ObjectId('54795ac4446f5279bd637c5e'), u'dpid': 29},
#  {u'_id': ObjectId('54795ac4446f5279bd637c5f'), u'dpid': 30},
#  {u'_id': ObjectId('54795ac4446f5279bd637c61'), u'dpid': 31},
#  {u'_id': ObjectId('54795ac4446f5279bd637c62'), u'dpid': 32},
#  {u'_id': ObjectId('54795ac4446f5279bd637c63'), u'dpid': 33},
#  {u'_id': ObjectId('54795ac4446f5279bd637cc2'), u'dpid': 112},
#  {u'_id': ObjectId('54795ac4446f5279bd637cc3'), u'dpid': 113},
#  {u'_id': ObjectId('54795ac4446f5279bd637cc4'), u'dpid': 114},
#  {u'_id': ObjectId('54795ac4446f5279bd637cc5'), u'dpid': 115},
#  {u'_id': ObjectId('54795ac4446f5279bd637cc7'), u'dpid': 116},
#  {u'_id': ObjectId('54795ac4446f5279bd637cc8'), u'dpid': 117},
#  {u'_id': ObjectId('54795ac4446f5279bd637cc9'), u'dpid': 118},
#  {u'_id': ObjectId('54795ac4446f5279bd637cca'), u'dpid': 119},
#  {u'_id': ObjectId('54795ac4446f5279bd637ccb'), u'dpid': 120},
#  {u'_id': ObjectId('54795ac4446f5279bd637ccd'), u'dpid': 121},
#  {u'_id': ObjectId('54795ac4446f5279bd637cce'), u'dpid': 122},
#  {u'_id': ObjectId('54795ac4446f5279bd637ccf'), u'dpid': 123},
#  {u'_id': ObjectId('54795ac4446f5279bd637cd0'), u'dpid': 124},
#  {u'_id': ObjectId('54795ac4446f5279bd637cd1'), u'dpid': 125}]

# %%
f.designs
# Out:
# [<dbmap.Design at 0x7f7d99041a50>,
#  <dbmap.Design at 0x7f7d993378d0>,
#  <dbmap.Design at 0x7f7d99041b90>,
#  <dbmap.Design at 0x7f7d99041910>,
#  <dbmap.Design at 0x7f7d99041d10>,
#  <dbmap.Design at 0x7f7d98fe8790>,
#  <dbmap.Design at 0x7f7d98fe8450>,
#  <dbmap.Design at 0x7f7d98fe8350>,
#  <dbmap.Design at 0x7f7d98fe8390>,
#  <dbmap.Design at 0x7f7d98fe8c90>,
#  <dbmap.Design at 0x7f7d98fe8290>,
#  <dbmap.Design at 0x7f7d98fe84d0>,
#  <dbmap.Design at 0x7f7d99041ad0>,
#  <dbmap.Design at 0x7f7d98fe8650>,
#  <dbmap.Design at 0x7f7d98fe8050>,
#  <dbmap.Design at 0x7f7d98fe8990>,
#  <dbmap.Design at 0x7f7d98fe8e10>,
#  <dbmap.Design at 0x7f7d98ff0a90>,
#  <dbmap.Design at 0x7f7d98ff0150>,
#  <dbmap.Design at 0x7f7d98ff0650>,
#  <dbmap.Design at 0x7f7d99041490>,
#  <dbmap.Design at 0x7f7d99056f10>,
#  <dbmap.Design at 0x7f7d990bf0d0>,
#  <dbmap.Design at 0x7f7d9937f3d0>,
#  <dbmap.Design at 0x7f7d990ac810>]

# %%
import dnaplotlib

# %%
reload(dnaplotlib)
# Out:
# <module 'dnaplotlib' from '/media/storage/EG/code/dnaplotlib/dnaplotlib.pyc'>

# %%
designs = [des.plot()[1] for des in f.designs]

# %%
designs
# Out:
# [[{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c35'),
#     u'color': [0.95, 0.3, 0.25],
#     u'part_name': u'P_BM3R1',
#     u'pid': 6},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c30'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_AmtR',
#     u'pid': 1},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c35'),
#     u'color': [0.95, 0.3, 0.25],
#     u'part_name': u'P_BM3R1',
#     u'pid': 6},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c31'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_LitR',
#     u'pid': 2},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c35'),
#     u'color': [0.95, 0.3, 0.25],
#     u'part_name': u'P_BM3R1',
#     u'pid': 6},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c32'),
#     u'color': [0.95, 0.3, 0.25],
#     u'label': u'BM3R1',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_BM3R1',
#     u'pid': 3},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c35'),
#     u'color': [0.95, 0.3, 0.25],
#     u'part_name': u'P_BM3R1',
#     u'pid': 6},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c33'),
#     u'color': [0.38, 0.65, 0.87],
#     u'label': u'SrpR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_SrpR',
#     u'pid': 4},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c35'),
#     u'color': [0.95, 0.3, 0.25],
#     u'part_name': u'P_BM3R1',
#     u'pid': 6},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c34'),
#     u'color': [0.55, 0.35, 0.64],
#     u'label': u'PhlF',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_PhlF',
#     u'pid': 5},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c36'),
#     u'color': [1.0, 0.75, 0.17],
#     u'part_name': u'P_AmtR',
#     u'pid': 7},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c30'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_AmtR',
#     u'pid': 1},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c36'),
#     u'color': [1.0, 0.75, 0.17],
#     u'part_name': u'P_AmtR',
#     u'pid': 7},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c31'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_LitR',
#     u'pid': 2},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c36'),
#     u'color': [1.0, 0.75, 0.17],
#     u'part_name': u'P_AmtR',
#     u'pid': 7},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c32'),
#     u'color': [0.95, 0.3, 0.25],
#     u'label': u'BM3R1',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_BM3R1',
#     u'pid': 3},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c36'),
#     u'color': [1.0, 0.75, 0.17],
#     u'part_name': u'P_AmtR',
#     u'pid': 7},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c33'),
#     u'color': [0.38, 0.65, 0.87],
#     u'label': u'SrpR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_SrpR',
#     u'pid': 4},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c36'),
#     u'color': [1.0, 0.75, 0.17],
#     u'part_name': u'P_AmtR',
#     u'pid': 7},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c34'),
#     u'color': [0.55, 0.35, 0.64],
#     u'label': u'PhlF',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_PhlF',
#     u'pid': 5},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c37'),
#     u'color': [0.38, 0.82, 0.32],
#     u'part_name': u'P_LitR',
#     u'pid': 8},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c30'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_AmtR',
#     u'pid': 1},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c37'),
#     u'color': [0.38, 0.82, 0.32],
#     u'part_name': u'P_LitR',
#     u'pid': 8},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c31'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_LitR',
#     u'pid': 2},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c37'),
#     u'color': [0.38, 0.82, 0.32],
#     u'part_name': u'P_LitR',
#     u'pid': 8},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c32'),
#     u'color': [0.95, 0.3, 0.25],
#     u'label': u'BM3R1',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_BM3R1',
#     u'pid': 3},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c37'),
#     u'color': [0.38, 0.82, 0.32],
#     u'part_name': u'P_LitR',
#     u'pid': 8},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c33'),
#     u'color': [0.38, 0.65, 0.87],
#     u'label': u'SrpR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_SrpR',
#     u'pid': 4},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c37'),
#     u'color': [0.38, 0.82, 0.32],
#     u'part_name': u'P_LitR',
#     u'pid': 8},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c34'),
#     u'color': [0.55, 0.35, 0.64],
#     u'label': u'PhlF',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_PhlF',
#     u'pid': 5},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c38'),
#     u'color': [0.38, 0.65, 0.87],
#     u'part_name': u'P_SrpR',
#     u'pid': 9},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c30'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_AmtR',
#     u'pid': 1},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c38'),
#     u'color': [0.38, 0.65, 0.87],
#     u'part_name': u'P_SrpR',
#     u'pid': 9},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c31'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_LitR',
#     u'pid': 2},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c38'),
#     u'color': [0.38, 0.65, 0.87],
#     u'part_name': u'P_SrpR',
#     u'pid': 9},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c32'),
#     u'color': [0.95, 0.3, 0.25],
#     u'label': u'BM3R1',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_BM3R1',
#     u'pid': 3},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c38'),
#     u'color': [0.38, 0.65, 0.87],
#     u'part_name': u'P_SrpR',
#     u'pid': 9},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c33'),
#     u'color': [0.38, 0.65, 0.87],
#     u'label': u'SrpR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_SrpR',
#     u'pid': 4},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c38'),
#     u'color': [0.38, 0.65, 0.87],
#     u'part_name': u'P_SrpR',
#     u'pid': 9},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c34'),
#     u'color': [0.55, 0.35, 0.64],
#     u'label': u'PhlF',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_PhlF',
#     u'pid': 5},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c39'),
#     u'color': [0.55, 0.35, 0.64],
#     u'part_name': u'P_PhlF',
#     u'pid': 10},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c30'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_AmtR',
#     u'pid': 1},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c39'),
#     u'color': [0.55, 0.35, 0.64],
#     u'part_name': u'P_PhlF',
#     u'pid': 10},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c31'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_LitR',
#     u'pid': 2},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c39'),
#     u'color': [0.55, 0.35, 0.64],
#     u'part_name': u'P_PhlF',
#     u'pid': 10},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c32'),
#     u'color': [0.95, 0.3, 0.25],
#     u'label': u'BM3R1',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_BM3R1',
#     u'pid': 3},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c39'),
#     u'color': [0.55, 0.35, 0.64],
#     u'part_name': u'P_PhlF',
#     u'pid': 10},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c33'),
#     u'color': [0.38, 0.65, 0.87],
#     u'label': u'SrpR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_SrpR',
#     u'pid': 4},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c39'),
#     u'color': [0.55, 0.35, 0.64],
#     u'part_name': u'P_PhlF',
#     u'pid': 10},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3a'),
#     u'linewidth': 1.0,
#     u'part_name': u'Z_Rib',
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3c'),
#     u'color': [0.0, 0.0, 0.0],
#     u'part_name': u'R_RBS',
#     u'pid': 13},
#    'start': 31,
#    'type': u'RBS'},
#   {'end': 160,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c34'),
#     u'color': [0.55, 0.35, 0.64],
#     u'label': u'PhlF',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'part_name': u'C_PhlF',
#     u'pid': 5},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 210,
#    'fwd': True,
#    'name': None,
#    'opts': {u'_id': ObjectId('54795ac3446f5279bd637c3b'),
#     u'part_name': u'T_Ter',
#     u'pid': 12},
#    'start': 161,
#    'type': u'Terminator'}]]

# %%
from pylab import *

# %%
figure(figsize=(20, 50))
axes = []
for num in range(len(designs)):
    axes.append(subplot(len(designs), 1, num+1))
dnaplotlib.plot_sbol_designs(axes, designs)
# Out:
# ([-0.81, 81.81], [-35, 35])

# %%
print ax
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
dnaplotlib.plot_sbol_designs([ax], [design[1]])
# Out:
# ([-5.42, 547.42], [-35, 35])

# %%
show()

# %%
fig.savefig("test.pdf")

# %%
plt.close('all')
