# %%
import interact
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
f = interact.connection()

# %%
f.import_parts(interact.parse_data(open('../library_generation/projects/combo_test/parts.tab', "U")))

# %%
f.import_designs(interact.parse_data(open('../library_generation/projects/combo_test/designs.tab', "U")))

# %%
import dnaplotlib

# %%
designs = [des.plot()[1] for des in f.designs]

# %%
designs
# Out:
# [[{'end': 25,
#    'fwd': True,
#    'name': u'P_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309d'),
#     u'color': [0.38, 0.82, 0.32],
#     u'pid': 8},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 31,
#    'type': 'RBS'},
#   {'end': 210,
#    'fwd': True,
#    'name': u'C_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13097'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 2},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 260,
#    'fwd': True,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 211,
#    'type': u'Terminator'},
#   {'end': 285,
#    'fwd': True,
#    'name': u'P_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309c'),
#     u'color': [1.0, 0.75, 0.17],
#     u'pid': 7},
#    'start': 261,
#    'type': u'Promoter'},
#   {'end': 290,
#    'fwd': True,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 286,
#    'type': u'Ribozyme'},
#   {'end': 320,
#    'fwd': True,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 291,
#    'type': 'RBS'},
#   {'end': 520,
#    'fwd': True,
#    'name': u'C_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13096'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 1},
#    'start': 321,
#    'type': u'CDS'},
#   {'end': 570,
#    'fwd': True,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 521,
#    'type': u'Terminator'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': u'P_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309d'),
#     u'color': [0.38, 0.82, 0.32],
#     u'pid': 8},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 31,
#    'type': 'RBS'},
#   {'end': 210,
#    'fwd': True,
#    'name': u'C_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13097'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 2},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 260,
#    'fwd': True,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 211,
#    'type': u'Terminator'},
#   {'end': 261,
#    'fwd': False,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 310,
#    'type': u'Terminator'},
#   {'end': 311,
#    'fwd': False,
#    'name': u'C_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13096'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 1},
#    'start': 510,
#    'type': u'CDS'},
#   {'end': 511,
#    'fwd': False,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 540,
#    'type': 'RBS'},
#   {'end': 541,
#    'fwd': False,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 545,
#    'type': u'Ribozyme'},
#   {'end': 546,
#    'fwd': False,
#    'name': u'P_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309c'),
#     u'color': [1.0, 0.75, 0.17],
#     u'pid': 7},
#    'start': 570,
#    'type': u'Promoter'}],
#  [{'end': 25,
#    'fwd': True,
#    'name': u'P_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309c'),
#     u'color': [1.0, 0.75, 0.17],
#     u'pid': 7},
#    'start': 1,
#    'type': u'Promoter'},
#   {'end': 30,
#    'fwd': True,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 26,
#    'type': u'Ribozyme'},
#   {'end': 60,
#    'fwd': True,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 31,
#    'type': 'RBS'},
#   {'end': 260,
#    'fwd': True,
#    'name': u'C_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13096'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 1},
#    'start': 61,
#    'type': u'CDS'},
#   {'end': 310,
#    'fwd': True,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 261,
#    'type': u'Terminator'},
#   {'end': 335,
#    'fwd': True,
#    'name': u'P_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309d'),
#     u'color': [0.38, 0.82, 0.32],
#     u'pid': 8},
#    'start': 311,
#    'type': u'Promoter'},
#   {'end': 340,
#    'fwd': True,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 336,
#    'type': u'Ribozyme'},
#   {'end': 370,
#    'fwd': True,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 341,
#    'type': 'RBS'},
#   {'end': 520,
#    'fwd': True,
#    'name': u'C_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13097'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 2},
#    'start': 371,
#    'type': u'CDS'},
#   {'end': 570,
#    'fwd': True,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 521,
#    'type': u'Terminator'}],
#  [{'end': 1,
#    'fwd': False,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 50,
#    'type': u'Terminator'},
#   {'end': 51,
#    'fwd': False,
#    'name': u'C_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13096'),
#     u'color': [1.0, 0.75, 0.17],
#     u'label': u'AmtR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 1},
#    'start': 250,
#    'type': u'CDS'},
#   {'end': 251,
#    'fwd': False,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 280,
#    'type': 'RBS'},
#   {'end': 281,
#    'fwd': False,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 285,
#    'type': u'Ribozyme'},
#   {'end': 286,
#    'fwd': False,
#    'name': u'P_AmtR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309c'),
#     u'color': [1.0, 0.75, 0.17],
#     u'pid': 7},
#    'start': 310,
#    'type': u'Promoter'},
#   {'end': 335,
#    'fwd': True,
#    'name': u'P_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc1309d'),
#     u'color': [0.38, 0.82, 0.32],
#     u'pid': 8},
#    'start': 311,
#    'type': u'Promoter'},
#   {'end': 340,
#    'fwd': True,
#    'name': u'Z_Rib',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a0'),
#     u'linewidth': 1.0,
#     u'pid': 11},
#    'start': 336,
#    'type': u'Ribozyme'},
#   {'end': 370,
#    'fwd': True,
#    'name': 'R_RBS',
#    'opts': {'_id': ObjectId('5480d610446f5273abc130a2'),
#     'color': [0.0, 0.0, 0.0],
#     'pid': 13},
#    'start': 341,
#    'type': 'RBS'},
#   {'end': 520,
#    'fwd': True,
#    'name': u'C_LitR',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc13097'),
#     u'color': [0.38, 0.82, 0.32],
#     u'label': u'LitR',
#     u'label_style': u'italic',
#     u'label_x_offset': -2.0,
#     u'label_y_offset': -0.5,
#     u'linewidth': 1.0,
#     u'pid': 2},
#    'start': 371,
#    'type': u'CDS'},
#   {'end': 570,
#    'fwd': True,
#    'name': u'T_Ter',
#    'opts': {u'_id': ObjectId('5480d610446f5273abc130a1'), u'pid': 12},
#    'start': 521,
#    'type': u'Terminator'}]]

# %%
from pylab import *

# %%
figure(figsize=(10, 10))
axes = []
for num in range(len(designs)):
    axes.append(subplot(len(designs), 1, num+1))
dnaplotlib.plot_sbol_designs(axes, designs)
# Out:
# ([-1.62, 163.62], [-35, 35])
