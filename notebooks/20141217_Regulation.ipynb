# %%
import interact
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
f = interact.connection()

# %%
f.import_parts(interact.parse_data(open('../library_generation/projects/combo_test/parts.tab', "U")))

# %%
f.import_designs(interact.parse_data(open('../library_generation/projects/combo_test/designs.tab', "U")))

# %%
import dnaplotlib

# %%
names, designs, regs = zip(*[des.plot() for des in f.designs])

# %%
designs, regs
# Out:
# (([{'end': 25,
#     'fwd': True,
#     'name': u'P_LitR',
#     'opts': {'_id': '54931a71446f525052aeca9a',
#      'color': [0.38, 0.82, 0.32],
#      'pid': 8},
#     'start': 1,
#     'type': u'Promoter'},
#    {'end': 30,
#     'fwd': True,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 26,
#     'type': u'Ribozyme'},
#    {'end': 60,
#     'fwd': True,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 31,
#     'type': 'RBS'},
#    {'end': 210,
#     'fwd': True,
#     'name': 'C_LitR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#      'color': [0.38, 0.82, 0.32],
#      'label': 'LitR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 2},
#     'start': 61,
#     'type': 'CDS'},
#    {'end': 260,
#     'fwd': True,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 211,
#     'type': u'Terminator'},
#    {'end': 285,
#     'fwd': True,
#     'name': u'P_AmtR',
#     'opts': {'_id': '54931a71446f525052aeca99',
#      'color': [1.0, 0.75, 0.17],
#      'pid': 7},
#     'start': 261,
#     'type': u'Promoter'},
#    {'end': 290,
#     'fwd': True,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 286,
#     'type': u'Ribozyme'},
#    {'end': 320,
#     'fwd': True,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 291,
#     'type': 'RBS'},
#    {'end': 520,
#     'fwd': True,
#     'name': 'C_AmtR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#      'color': [1.0, 0.75, 0.17],
#      'label': 'AmtR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 1},
#     'start': 321,
#     'type': 'CDS'},
#    {'end': 570,
#     'fwd': True,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 521,
#     'type': u'Terminator'}],
#   [{'end': 25,
#     'fwd': True,
#     'name': u'P_LitR',
#     'opts': {'_id': '54931a71446f525052aeca9a',
#      'color': [0.38, 0.82, 0.32],
#      'pid': 8},
#     'start': 1,
#     'type': u'Promoter'},
#    {'end': 30,
#     'fwd': True,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 26,
#     'type': u'Ribozyme'},
#    {'end': 60,
#     'fwd': True,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 31,
#     'type': 'RBS'},
#    {'end': 210,
#     'fwd': True,
#     'name': 'C_LitR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#      'color': [0.38, 0.82, 0.32],
#      'label': 'LitR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 2},
#     'start': 61,
#     'type': 'CDS'},
#    {'end': 260,
#     'fwd': True,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 211,
#     'type': u'Terminator'},
#    {'end': 261,
#     'fwd': False,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 310,
#     'type': u'Terminator'},
#    {'end': 311,
#     'fwd': False,
#     'name': 'C_AmtR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#      'color': [1.0, 0.75, 0.17],
#      'label': 'AmtR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 1},
#     'start': 510,
#     'type': 'CDS'},
#    {'end': 511,
#     'fwd': False,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 540,
#     'type': 'RBS'},
#    {'end': 541,
#     'fwd': False,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 545,
#     'type': u'Ribozyme'},
#    {'end': 546,
#     'fwd': False,
#     'name': u'P_AmtR',
#     'opts': {'_id': '54931a71446f525052aeca99',
#      'color': [1.0, 0.75, 0.17],
#      'pid': 7},
#     'start': 570,
#     'type': u'Promoter'}],
#   [{'end': 25,
#     'fwd': True,
#     'name': u'P_AmtR',
#     'opts': {'_id': '54931a71446f525052aeca99',
#      'color': [1.0, 0.75, 0.17],
#      'pid': 7},
#     'start': 1,
#     'type': u'Promoter'},
#    {'end': 30,
#     'fwd': True,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 26,
#     'type': u'Ribozyme'},
#    {'end': 60,
#     'fwd': True,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 31,
#     'type': 'RBS'},
#    {'end': 260,
#     'fwd': True,
#     'name': 'C_AmtR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#      'color': [1.0, 0.75, 0.17],
#      'label': 'AmtR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 1},
#     'start': 61,
#     'type': 'CDS'},
#    {'end': 310,
#     'fwd': True,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 261,
#     'type': u'Terminator'},
#    {'end': 335,
#     'fwd': True,
#     'name': u'P_LitR',
#     'opts': {'_id': '54931a71446f525052aeca9a',
#      'color': [0.38, 0.82, 0.32],
#      'pid': 8},
#     'start': 311,
#     'type': u'Promoter'},
#    {'end': 340,
#     'fwd': True,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 336,
#     'type': u'Ribozyme'},
#    {'end': 370,
#     'fwd': True,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 341,
#     'type': 'RBS'},
#    {'end': 520,
#     'fwd': True,
#     'name': 'C_LitR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#      'color': [0.38, 0.82, 0.32],
#      'label': 'LitR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 2},
#     'start': 371,
#     'type': 'CDS'},
#    {'end': 570,
#     'fwd': True,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 521,
#     'type': u'Terminator'}],
#   [{'end': 1,
#     'fwd': False,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 50,
#     'type': u'Terminator'},
#    {'end': 51,
#     'fwd': False,
#     'name': 'C_AmtR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#      'color': [1.0, 0.75, 0.17],
#      'label': 'AmtR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 1},
#     'start': 250,
#     'type': 'CDS'},
#    {'end': 251,
#     'fwd': False,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 280,
#     'type': 'RBS'},
#    {'end': 281,
#     'fwd': False,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 285,
#     'type': u'Ribozyme'},
#    {'end': 286,
#     'fwd': False,
#     'name': u'P_AmtR',
#     'opts': {'_id': '54931a71446f525052aeca99',
#      'color': [1.0, 0.75, 0.17],
#      'pid': 7},
#     'start': 310,
#     'type': u'Promoter'},
#    {'end': 335,
#     'fwd': True,
#     'name': u'P_LitR',
#     'opts': {'_id': '54931a71446f525052aeca9a',
#      'color': [0.38, 0.82, 0.32],
#      'pid': 8},
#     'start': 311,
#     'type': u'Promoter'},
#    {'end': 340,
#     'fwd': True,
#     'name': u'Z_Rib',
#     'opts': {'_id': '54931a71446f525052aeca9d', 'linewidth': 1.0, 'pid': 11},
#     'start': 336,
#     'type': u'Ribozyme'},
#    {'end': 370,
#     'fwd': True,
#     'name': 'R_RBS',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca9f'),
#      'color': [0.0, 0.0, 0.0],
#      'pid': 13},
#     'start': 341,
#     'type': 'RBS'},
#    {'end': 520,
#     'fwd': True,
#     'name': 'C_LitR',
#     'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#      'color': [0.38, 0.82, 0.32],
#      'label': 'LitR',
#      'label_style': 'italic',
#      'label_x_offset': -2.0,
#      'label_y_offset': -0.5,
#      'linewidth': 1.0,
#      'pid': 2},
#     'start': 371,
#     'type': 'CDS'},
#    {'end': 570,
#     'fwd': True,
#     'name': u'T_Ter',
#     'opts': {'_id': '54931a71446f525052aeca9e', 'pid': 12},
#     'start': 521,
#     'type': u'Terminator'}]),
#  ([{'from_part': {'end': 210,
#      'fwd': True,
#      'name': 'C_LitR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#       'color': [0.38, 0.82, 0.32],
#       'label': 'LitR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 2},
#      'start': 61,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa1',
#      'color': [0.38, 0.82, 0.32],
#      'rid': 2},
#     'to_part': {'end': 285,
#      'fwd': True,
#      'name': u'P_AmtR',
#      'opts': {'_id': '54931a71446f525052aeca99',
#       'color': [1.0, 0.75, 0.17],
#       'pid': 7},
#      'start': 261,
#      'type': u'Promoter'},
#     'type': 'Repression'},
#    {'from_part': {'end': 520,
#      'fwd': True,
#      'name': 'C_AmtR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#       'color': [1.0, 0.75, 0.17],
#       'label': 'AmtR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 1},
#      'start': 321,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa0',
#      'color': [1.0, 0.75, 0.17],
#      'rid': 1},
#     'to_part': {'end': 25,
#      'fwd': True,
#      'name': u'P_LitR',
#      'opts': {'_id': '54931a71446f525052aeca9a',
#       'color': [0.38, 0.82, 0.32],
#       'pid': 8},
#      'start': 1,
#      'type': u'Promoter'},
#     'type': 'Repression'}],
#   [{'from_part': {'end': 210,
#      'fwd': True,
#      'name': 'C_LitR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#       'color': [0.38, 0.82, 0.32],
#       'label': 'LitR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 2},
#      'start': 61,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa1',
#      'color': [0.38, 0.82, 0.32],
#      'rid': 2},
#     'to_part': {'end': 546,
#      'fwd': False,
#      'name': u'P_AmtR',
#      'opts': {'_id': '54931a71446f525052aeca99',
#       'color': [1.0, 0.75, 0.17],
#       'pid': 7},
#      'start': 570,
#      'type': u'Promoter'},
#     'type': 'Repression'},
#    {'from_part': {'end': 311,
#      'fwd': False,
#      'name': 'C_AmtR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#       'color': [1.0, 0.75, 0.17],
#       'label': 'AmtR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 1},
#      'start': 510,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa0',
#      'color': [1.0, 0.75, 0.17],
#      'rid': 1},
#     'to_part': {'end': 25,
#      'fwd': True,
#      'name': u'P_LitR',
#      'opts': {'_id': '54931a71446f525052aeca9a',
#       'color': [0.38, 0.82, 0.32],
#       'pid': 8},
#      'start': 1,
#      'type': u'Promoter'},
#     'type': 'Repression'}],
#   [{'from_part': {'end': 260,
#      'fwd': True,
#      'name': 'C_AmtR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#       'color': [1.0, 0.75, 0.17],
#       'label': 'AmtR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 1},
#      'start': 61,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa0',
#      'color': [1.0, 0.75, 0.17],
#      'rid': 1},
#     'to_part': {'end': 335,
#      'fwd': True,
#      'name': u'P_LitR',
#      'opts': {'_id': '54931a71446f525052aeca9a',
#       'color': [0.38, 0.82, 0.32],
#       'pid': 8},
#      'start': 311,
#      'type': u'Promoter'},
#     'type': 'Repression'},
#    {'from_part': {'end': 520,
#      'fwd': True,
#      'name': 'C_LitR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#       'color': [0.38, 0.82, 0.32],
#       'label': 'LitR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 2},
#      'start': 371,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa1',
#      'color': [0.38, 0.82, 0.32],
#      'rid': 2},
#     'to_part': {'end': 25,
#      'fwd': True,
#      'name': u'P_AmtR',
#      'opts': {'_id': '54931a71446f525052aeca99',
#       'color': [1.0, 0.75, 0.17],
#       'pid': 7},
#      'start': 1,
#      'type': u'Promoter'},
#     'type': 'Repression'}],
#   [{'from_part': {'end': 51,
#      'fwd': False,
#      'name': 'C_AmtR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca93'),
#       'color': [1.0, 0.75, 0.17],
#       'label': 'AmtR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 1},
#      'start': 250,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa0',
#      'color': [1.0, 0.75, 0.17],
#      'rid': 1},
#     'to_part': {'end': 335,
#      'fwd': True,
#      'name': u'P_LitR',
#      'opts': {'_id': '54931a71446f525052aeca9a',
#       'color': [0.38, 0.82, 0.32],
#       'pid': 8},
#      'start': 311,
#      'type': u'Promoter'},
#     'type': 'Repression'},
#    {'from_part': {'end': 520,
#      'fwd': True,
#      'name': 'C_LitR',
#      'opts': {'_id': ObjectId('54931a71446f525052aeca94'),
#       'color': [0.38, 0.82, 0.32],
#       'label': 'LitR',
#       'label_style': 'italic',
#       'label_x_offset': -2.0,
#       'label_y_offset': -0.5,
#       'linewidth': 1.0,
#       'pid': 2},
#      'start': 371,
#      'type': 'CDS'},
#     'opts': {'_id': '54931a71446f525052aecaa1',
#      'color': [0.38, 0.82, 0.32],
#      'rid': 2},
#     'to_part': {'end': 286,
#      'fwd': False,
#      'name': u'P_AmtR',
#      'opts': {'_id': '54931a71446f525052aeca99',
#       'color': [1.0, 0.75, 0.17],
#       'pid': 7},
#      'start': 310,
#      'type': u'Promoter'},
#     'type': 'Repression'}]))

# %%
from pylab import *

# %%
figure(figsize=(10, 10))
axes = []
for num in range(len(designs)):
    axes.append(subplot(len(designs), 1, num+1))
dnaplotlib.plot_sbol_designs(axes, designs, regulations=regs)
# Out:
# {'color': [0.38, 0.82, 0.32], 'rid': 2, '_id': '54931a71446f525052aecaa1'}
# [0.38, 0.82, 0.32]
# {'color': [1.0, 0.75, 0.17], 'rid': 1, '_id': '54931a71446f525052aecaa0'}
# [1.0, 0.75, 0.17]
# {'color': [0.38, 0.82, 0.32], 'rid': 2, '_id': '54931a71446f525052aecaa1'}
# [0.38, 0.82, 0.32]
# {'color': [1.0, 0.75, 0.17], 'rid': 1, '_id': '54931a71446f525052aecaa0'}
# [1.0, 0.75, 0.17]
# {'color': [1.0, 0.75, 0.17], 'rid': 1, '_id': '54931a71446f525052aecaa0'}
# [1.0, 0.75, 0.17]
# {'color': [0.38, 0.82, 0.32], 'rid': 2, '_id': '54931a71446f525052aecaa1'}
# [0.38, 0.82, 0.32]
# {'color': [1.0, 0.75, 0.17], 'rid': 1, '_id': '54931a71446f525052aecaa0'}
# [1.0, 0.75, 0.17]
# {'color': [0.38, 0.82, 0.32], 'rid': 2, '_id': '54931a71446f525052aecaa1'}
# [0.38, 0.82, 0.32]
# ([-1.62, 163.62], [-35, 35])
