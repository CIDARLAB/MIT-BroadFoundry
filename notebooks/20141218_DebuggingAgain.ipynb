# %%
import interact
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
connect = interact.connection()

# %%
connect.import_parts(interact.parse_data(open('../library_generation/projects/cello/parts.tab', "U")))

# %%
data = interact.parse_data(open('../library_generation/projects/cello/simple_designs.tab', "U"))

# %%
for design_dict in data:
    for vlist in connect.spec_parse(design_dict['spec']):
        print vlist
# Out:
# spec ((name:input_pTac+name:SarJ+name:js2_bm3r1+name:BM3R1+name:L3S2P11)*(name:pQacR+name:PlmJ+name:an2_litr+name:LitR+name:L3S2P24)*(name:pBM3R1+name:pLitR+name:RiboJ53+name:an1_phlf+name:PhlF+name:ECK120033737))+(name:pPhlF+name:output_YFP)
# separated ['(name:input_pTac+name:SarJ+name:js2_bm3r1+name:BM3R1+name:L3S2P11)*(name:pQacR+name:PlmJ+name:an2_litr+name:LitR+name:L3S2P24)*(name:pBM3R1+name:pLitR+name:RiboJ53+name:an1_phlf+name:PhlF+name:ECK120033737)', '+', 'name:pPhlF+name:output_YFP']
# spec (name:input_pTac+name:SarJ+name:js2_bm3r1+name:BM3R1+name:L3S2P11)*(name:pQacR+name:PlmJ+name:an2_litr+name:LitR+name:L3S2P24)*(name:pBM3R1+name:pLitR+name:RiboJ53+name:an1_phlf+name:PhlF+name:ECK120033737)
# separated ['name:input_pTac+name:SarJ+name:js2_bm3r1+name:BM3R1+name:L3S2P11', '*', 'name:pQacR+name:PlmJ+name:an2_litr+name:LitR+name:L3S2P24', '*', 'name:pBM3R1+name:pLitR+name:RiboJ53+name:an1_phlf+name:PhlF+name:ECK120033737']
# ...

# %%
import dnaplotlib

# %%
import random

# %%
len(connect.designs)
# Out:
# 0

# %%
names, designs, regs = zip(*[des.plot() for des in connect.designs])

# %%
for design, reg in zip(designs, regs):
    for part in design:
        print part
    print reg
    print
# Out:
# {'end': 15, 'name': u'input_pTac', 'fwd': True, 'start': 1, 'type': u'Promoter', 'opts': {'color': [0.0, 0.0, 0.0], '_id': '54933bd5446f52571461f1c5', 'pid': 7}}
# {'end': 25, 'name': u'SarJ', 'fwd': True, 'start': 16, 'type': u'Ribozyme', 'opts': {'color': [0.2, 0.63, 0.17], '_id': '54933bd5446f52571461f1d7', 'pid': 25}}
# {'end': 35, 'name': u'js2_bm3r1', 'fwd': True, 'start': 26, 'type': u'RBS', 'opts': {'color': [0.2, 0.63, 0.17], '_id': '54933bd5446f52571461f1cf', 'pid': 17}}
# {'end': 95, 'name': 'BM3R1', 'fwd': True, 'start': 36, 'type': 'CDS', 'opts': {'color': [0.2, 0.63, 0.17], '_id': ObjectId('54933bd5446f52571461f1cb'), 'pid': 13}}
# {'end': 115, 'name': u'L3S2P11', 'fwd': True, 'start': 96, 'type': u'Terminator', 'opts': {'color': [0.2, 0.63, 0.17], '_id': '54933bd5446f52571461f1c3', 'pid': 5}}
# {'end': 130, 'name': u'pQacR', 'fwd': True, 'start': 116, 'type': u'Promoter', 'opts': {'color': [0.98, 0.6, 0.6], '_id': '54933bd5446f52571461f1c7', 'pid': 9}}
# ...

# %%
figure(figsize=(20, 60))
axes = []
for num in range(len(designs)):
    axes.append(subplot(len(designs), 1, num+1))
dnaplotlib.plot_sbol_designs(axes, designs, regulations=regs)
# Out:
# ([-3.0300000000000002, 306.03], [-35, 35])
