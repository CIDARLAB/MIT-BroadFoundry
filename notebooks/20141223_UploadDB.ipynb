# %%
import interact
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
rm clotho.db
# Out:
# rm: cannot remove ‘clotho.db’: No such file or directory

# %%
connect = interact.connection('clotho.db', 'clotho')

# %%
connect.import_parts(interact.parse_data(open('../library_generation/projects/cello/parts.tab', "U")))

# %%
connect.import_designs(interact.parse_data(open('../library_generation/projects/cello/short_designs.tab', "U")))

# %%
connect.load_db()

# %%
names, designs, regs = zip(*[des.plot() for des in connect.designs])

# %%
import dnaplotlib

# %%
figure(figsize=(, 50))
axes = []
for num in range(len(designs)):
    axes.append(subplot(len(designs), 1, num+1))
dnaplotlib.plot_sbol_designs(axes, designs, regulations=regs)
# Out:
# ([-3.0300000000000002, 306.03], [-35, 35])

# %%
connect.disconnect()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8694fbf3a743> in <module>()
# ----> 1 connect.disconnect()
#
# /media/storage/EG/code/library_generation/interact.pyc in disconnect(self)
#      92
#      93         def disconnect(self):
# ---> 94                 dbmap.close_all()
#      95
#      96         def dict_match(self, match_type, match_dict, match_columns = []):
#
# /media/storage/EG/code/library_generation/dbmap.py in close_all()
#      64         session.commit()
#      65         session.close()
# ---> 66         mdb.close()
#      67
#      68 def uni_to_str(dictionary):
#
# /usr/local/lib/python2.7/dist-packages/pymongo/collection.pyc in __call__(self, *args, **kwargs)
#    1703                             "object it is failing because no such method "
#    1704                             "exists." %
# -> 1705                             self.__name)
#    1706         raise TypeError("'Collection' object is not callable. If you meant to "
#    1707                         "call the '%s' method on a 'Collection' object it is "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'close' method on a 'Database' object it is failing because no such method exists.

# %%
connect = interact.connection('clotho.db', 'clotho')

# %%
connect.load_db()

# %%
connect.designs
# Out:
# [<dbmap.Design at 0x7f77fdb4b1d0>,
#  <dbmap.Design at 0x7f77fdcab610>,
#  <dbmap.Design at 0x7f77fdb4b290>,
#  <dbmap.Design at 0x7f77fdb4b390>,
#  <dbmap.Design at 0x7f77fdb4b450>,
#  <dbmap.Design at 0x7f77fdb4b550>,
#  <dbmap.Design at 0x7f77fdb4b650>,
#  <dbmap.Design at 0x7f77fdb4b750>,
#  <dbmap.Design at 0x7f77fdb4b850>,
#  <dbmap.Design at 0x7f77fdb4b950>,
#  <dbmap.Design at 0x7f77fdb4ba50>,
#  <dbmap.Design at 0x7f77fdb4bb50>,
#  <dbmap.Design at 0x7f77fdb4bc50>,
#  <dbmap.Design at 0x7f77fdb4bd50>,
#  <dbmap.Design at 0x7f77fdb4be50>,
#  <dbmap.Design at 0x7f77fdb4bf50>,
#  <dbmap.Design at 0x7f77fdb52050>,
#  <dbmap.Design at 0x7f77fdb52150>,
#  <dbmap.Design at 0x7f77fdb52250>,
#  <dbmap.Design at 0x7f77fdb52350>,
#  <dbmap.Design at 0x7f77fdb52450>,
#  <dbmap.Design at 0x7f77fdb52550>,
#  <dbmap.Design at 0x7f77fdb52650>,
#  <dbmap.Design at 0x7f77fdb52750>,
#  <dbmap.Design at 0x7f77fdb52850>,
#  <dbmap.Design at 0x7f77fdb52950>,
#  <dbmap.Design at 0x7f77fdb52a50>,
#  <dbmap.Design at 0x7f77fdb52b50>,
#  <dbmap.Design at 0x7f77fdb52c50>,
#  <dbmap.Design at 0x7f77fdb52d50>,
#  <dbmap.Design at 0x7f77fdb52e50>,
#  <dbmap.Design at 0x7f77fdb52f50>,
#  <dbmap.Design at 0x7f77fdb5c090>,
#  <dbmap.Design at 0x7f77fdb5c190>,
#  <dbmap.Design at 0x7f77fdb733d0>,
#  <dbmap.Design at 0x7f77fdb5c350>,
#  <dbmap.Design at 0x7f77fdb5c3d0>,
#  <dbmap.Design at 0x7f77fdb5c4d0>,
#  <dbmap.Design at 0x7f77fdb5c5d0>,
#  <dbmap.Design at 0x7f77fdb5c6d0>,
#  <dbmap.Design at 0x7f77fdb5c7d0>,
#  <dbmap.Design at 0x7f77fdb5c8d0>,
#  <dbmap.Design at 0x7f77fdb5c9d0>,
#  <dbmap.Design at 0x7f77fdb5cad0>,
#  <dbmap.Design at 0x7f77fdb5cbd0>,
#  <dbmap.Design at 0x7f77fdb5ccd0>,
#  <dbmap.Design at 0x7f77fdb5cdd0>,
#  <dbmap.Design at 0x7f77fdb5ced0>]

# %%
import dnaplotlib

# %%
import random

# %%
len(connect.designs)
# Out:
# 46080

# %%
import random

# %%
names, designs, regs = zip(*[des.plot() for des in random.sample(connect.designs, 20)])

# %%
figure(figsize=(20, 50))
axes = []
for num in range(len(designs)):
    axes.append(subplot(len(designs), 1, num+1))
dnaplotlib.plot_sbol_designs(axes, designs, regulations=regs)
# Out:
# ([-5.6000000000000005, 565.6], [-35, 35])

# %%
connect.disconnect()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8694fbf3a743> in <module>()
# ----> 1 connect.disconnect()
#
# /media/storage/EG/code/library_generation/interact.py in disconnect(self)
#      92
#      93         def disconnect(self):
# ---> 94                 dbmap.close_all()
#      95
#      96         def dict_match(self, match_type, match_dict, match_columns = []):
#
# /media/storage/EG/code/library_generation/dbmap.pyc in close_all()
#      63 def close_all():
#      64         session.close()
# ---> 65         mdb.close()
#      66
#      67 def uni_to_str(dictionary):
#
# /usr/local/lib/python2.7/dist-packages/pymongo/collection.pyc in __call__(self, *args, **kwargs)
#    1703                             "object it is failing because no such method "
#    1704                             "exists." %
# -> 1705                             self.__name)
#    1706         raise TypeError("'Collection' object is not callable. If you meant to "
#    1707                         "call the '%s' method on a 'Collection' object it is "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'close' method on a 'Database' object it is failing because no such method exists.
